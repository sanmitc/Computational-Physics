# %% [markdown]
# Question 2

# %%
#part a
import math
def findHeight(T):
    G=6.67e-11
    M=5.9722e24
    R=6378.1e3
    h=((G*M*T**2)/(4*(math.pi)**2))**(1/3)-R
    h=h/1000
    return h

#part b
print("the height required for revolving in 1 day in km:", findHeight(86400)),
print("the height required for revolving in 90 minutes in km:", findHeight(5400)),
print("the height required for revolving in 45 minutes in km:", findHeight(2700))
# Out:
# the height required for revolving in 1 day in km: 35853.99654096109
# the height required for revolving in 90 minutes in km: 273.0384266436668
# the height required for revolving in 45 minutes in km: -2188.145345253488

# %% [markdown]
# This essentially tells us that as the heigh decreases,
# after a certain point the hypothesized height of the satelite will have to pass through below earth.
# So, there is a lower limit in the time of revolution of the satelite. That can even be calculatedy

# %%
G=6.67e-11
M=5.9722e24
R=6378.1e3
T=math.sqrt((4*R**3*math.pi**2)/(G*M))
print(T/3600,"hours or", T/60, "minutes")
# Out:
# 1.4085889113076024 hours or 84.51533467845614 minutes

# %% [markdown]
# Part c: The satelite rotates in such a way that it must be present on the same spot after 1 day. To achieve that the satelite should rotate around earth

# %%
print("The new height is",findHeight(23.93*3600))
p=findHeight(86400)-findHeight(23.93*3600)
print("Change in height", findHeight(86400)-findHeight(23.93*3600))
# Out:
# The new height is 35771.83860517497
# Change in height 82.1579357861192

# %% [markdown]
# Question 3

# %%
import math

#Here the convention is taken to be -pi to +pi

def Polar(x,y):
    theta=0
    r=math.sqrt(x**2+y**2)
    if(x!=0):
        if(x>0 and y>0):
            theta=(180/math.pi)*(math.atan(y/x))
        if(x>0 and y<0):
            theta=(180/math.pi)*(math.atan(y/x))
        if(x<0 and y>0):
            theta=(180/math.pi)*(math.atan(y/x))+180
        if(x<0 and y<0):
            theta=(180/math.pi)*(math.atan(y/x))-180
    else:
        if(y>0):
            theta=90
        else:
            theta=-90
    return [r,theta]

print('x value')
x=float(input())
print('y value')
y=float(input())
print("r is:", Polar(x,y)[0])
print("theta is:", Polar(x,y)[1])
# Out:
# x value
# 0
# y value
# 8
# r is: 8.0
# theta is: 90

# %% [markdown]
# Question 5

# %%
#part a, give v as a fraction of light speed
def time(x,v):
    t_1=x/v
    gamma=1/math.sqrt(1-(v/c)**2)
    t_2=x/(gamma*v)
    return [t_1,t_2]

#driver code
v=input()
x=[]
x.extend(v)
#print(x)
n=len(x)
x.pop(n-1)
#print(x)
str=""
for ele in x:
    str+=ele

v_in=int(str)
print(v)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [8], in <cell line: 14>()
#      12 #print(x)
#      13 n=len(x)
# ---> 14 x.pop(n-1)
#      15 #print(x)
#      16 str=""
#
# IndexError: pop from empty list

# %% [markdown]
# Question 11

# %%
import math
def prime(Num):
    arr=[2]
    for i in range(3,Num+1):
        k=int(math.sqrt(i))
        n=len(arr)
        counter=0
        for j in range(n):
            if(arr[j]>k):
                break
            elif(i%arr[j]==0):
                counter=1
                break
        if(counter==0):
            arr.append(i)
        #print(i, j)
    return arr

N=float(input())
N=int(N)
print("",prime(N))
print(len(prime(N)))
# Out:
# 7
#  [2, 3, 5, 7]
# 4

# %% [markdown]
# Question 12

# %%
#part a
def Catalan(n):
    p=0
    if(n==0):
        p=1
    else:
        p=((4*n+2)/(n+2))*Catalan(n-1)
    return int(p)

n=int(input())
print("Corresponding Catalan number is:", Catalan(n))

# For directly implementing C_100
#print("C_100 is:", Catalan(100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 10>()
#       7         p=((4*n+2)/(n+2))*Catalan(n-1)
#       8     return int(p)
# ---> 10 n=int(input())
#      11 print("Corresponding Catalan number is:", Catalan(n))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
#part b
def gcd(m,n):
    p=0
    if(n==0):
        p=m
    else:
        p=gcd(m,n%m)
    return p

#m=int(input())
#n=int(input())
print("The gcd is:", gcd(108,192))

# %%
#part a
import matplotlib.pyplot as plt

t = []
ss = []

file=open(r"sunspots.txt")


for rows in file:
        rows=rows.split('\t')
        t.append(int(rows[0]))
        ss.append(float(rows[1].strip()))
        #print(rows[1])
        
        
plt.bar(t, ss,color='k')
plt.title('Time variation of sunspot occurence')
plt.xlabel('sunspot no.')
plt.ylabel('no. of month')
plt.show()

# %% [markdown]
# Question 14

# %%
#part b

import matplotlib.pyplot as plt

t_n = []
ss_n = []

file=open(r"sunspots.txt")

i=0
for rows in file:
    if(i>1000):
        break
    else:
        rows=rows.split('\t')
        t_n.append(int(rows[0]))
        ss_n.append(float(rows[1].strip()))
        i+=1
        #print(rows[1])
              
plt.bar(t_n, ss_n,color='k')
plt.title('Time variation of sunspot occurence')
plt.xlabel('sunspot no.')
plt.ylabel('no. of month')
plt.show()

# %%
# part c
import statistics as stat

ss_mean=[]

for i in range(0,len(ss)):
    if(i>1000):
        break
    elif(i<5):
        ss_mean.append(stat.mean(ss_n[:i+6]))
    else:
        ss_mean.append(stat.mean(ss_n[i-5:i+6]))

plt.plot(t, ss,color='b')
plt.plot(t,ss_mean, color='g')
plt.title('Time variation of sunspot occurence(moving average)')
plt.xlabel('sunspot no.')
plt.ylabel('no. of month')
plt.show()

# %% [markdown]
# Question 14

# %%
#part a

import numpy as np
import math
import matplotlib.pyplot as plt

angle=np.linspace(0,2*math.pi, 200)
x=[]
y=[]
for i in range(200):
    x.append(2*math.cos(angle[i])+math.cos(2*angle[i]))
    y.append(2*math.sin(angle[i])-math.sin(2*angle[i]))
#print(theta)

plt.plot(x,y, color='g')
plt.xlabel('x')
plt.ylabel('y')
plt.title('deltoid curve')
plt.show()

# %%
#part b

import numpy as np
import math
import matplotlib.pyplot as plt

angle=np.linspace(0,10*math.pi, 500)

r=[]
x=[]
y=[]

for i in range(500):
    r.append(angle[i]**2)
    x.append(r[i]*math.cos(angle[i]))
    y.append(r[i]*math.sin(angle[i]))
    
plt.plot(x,y, color='g')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gallilean Spiral')
plt.show()

# %%
#part c

import numpy as np
import math
import matplotlib.pyplot as plt

angle=np.linspace(0,24*math.pi, 2000)

r=[]
x=[]
y=[]

for i in range(2000):
    r.append(np.exp(math.cos(angle[i])) - 2*math.cos(4*angle[i]) + (math.sin(angle[i]/12))**5)
    x.append(r[i]*math.cos(angle[i]))
    y.append(r[i]*math.sin(angle[i]))
    
plt.plot(x,y, color='g')
plt.xlabel('x')
plt.ylabel('y')
plt.title("Fey's function")
plt.show()

# %% [markdown]
# Question 15

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

file=open(r"stm.txt")

print(len(file))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [56], in <cell line: 7>()
#       3 import matplotlib.pyplot as plt
#       5 file=open(r"stm.txt")
# ----> 7 print(len(file))
#
# TypeError: object of type '_io.TextIOWrapper' has no len()

# %% [markdown]
# Question 16

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

r=np.linspace(1,4,300)
x=1/2
for k in range(200):
    y=[0]*300
    for j in range(300):
        y[k]=r[k]*x*(1-x)
        plt.scatter(r,y)
plt.xlabel(n)
plt.ylabel(x)
plt.title('deterministic chaos')
plt.show()

# %%
import numpy as np
x=np.linspace(-2,2,100)
[X,Y]=meshgrid(x,x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 import numpy as np
#       2 x=np.linspace(-2,2,100)
# ----> 3 [X,Y]=meshgrid(x,x)
#
# NameError: name 'meshgrid' is not defined

# %% [markdown]
# Question 17

# %%
import numpy as np
import math
import cmath
import matplotlib.pyplot as plt

x=np.linspace(-2,2,100)
y=np.linspace(-2,2,100)
[X,Y]=np.meshgrid(x,y)
def norm(x,y):
    return math.sqrt(x**2+y**2)
def colour(x,y):
    color=0
    z=complex(0,0)
    c=complex(x,y)
    for i in range(101):
        z = z**2 + c
        if(norm(z.imag,z.real)>2):
            color=1
            break
    return color

pt=colour(x,y)
cmap = plt.colors.ListedColormap(['white','black'])
bounds=[-1,0.5,2]
norm = plt.colors.BoundaryNorm(bounds, cmap.N)

img = pyplot.imshow(pt,interpolation='nearest',
                    cmap = cmap,norm=norm)

# make a color bar
plt.colorbar(img,cmap=cmap,
                norm=norm,boundaries=bounds)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 22>()
#      19             break
#      20     return color
# ---> 22 pt=colour(xx,yy)
#      23 cmap = plt.colors.ListedColormap(['white','black'])
#      24 bounds=[-1,0.5,2]
#
# NameError: name 'xx' is not defined

# %% [markdown]
# Question 18

# %%
import numpy as np
import math
import matplotlib.pyplot as plt



r=np.linspace(1,4,300)
y=[1/2]*300
for k in range(2000): 
    for j in range(300):
        y[k]=r[j]*y[k]*(1-y[k])
        plt.scatter(r,y)
plt.xlabel(n)
plt.ylabel(x)
plt.title('deterministic chaos')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math


file=open(r'stm.txt')
f=file.read()
f.split('/n')
#print(f)
    
n=0
for rows in file:
    rows=rows.split(' ')
    n+=len(rows)
    print(len(rows))

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

x=np.loadtxt(r'stm.txt')

rows=x.shape[0]
columns=x.shape[1]

plt.imshow(x, extend)
plt.xlabel('x coordinate')
plt.ylabel('y coordinate')

plt.title('stm height data plotted in a color plot')
