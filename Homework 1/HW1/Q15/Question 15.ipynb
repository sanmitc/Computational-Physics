# %%
import numpy as np
import math
import matplotlib.pyplot as plt

x=np.loadtxt(r'stm.txt')

rows=x.shape[0]
columns=x.shape[1]

plt.imshow(x)
plt.xlabel('x coordinate')
plt.ylabel('y coordinate')

plt.title('stm height data plotted in a color plot')
# Out:
# Text(0.5, 1.0, 'stm height data plotted in a color plot')
